# %%
import numpy as np
import random
import matplotlib.pyplot as plt


class LavenderGrowthEnv:
    def __init__(self):
        self.state = np.array([5000, 25, 60])  # light (lux), temp (°C), humidity (%)
        self.M0 = 5  # initial biomass
        self.M = self.M0
        self.conversion = 0.0185
        self.water_supply = 1
        self.stage_factor = 1
        self.red_light = 1 
        self.blue_light = 1
        self.gamma_base = 1.0
        self.rho_base = 0.05
        self.M_max = 1500 * 2

        self.max_days = 90
        self.day = 0

        self.light_range = (3000, 20000)
        self.temp_range = (15, 35)
        self.humidity_range = (30, 80)
        # for reset 
        self.light_reset_range = (7000, 10000)
        self.temp_reset_range = (25, 30)
        self.humidity_reset_range = (50, 60)

        self.action_steps = [-2, -1, 0, 1, 2]
        self.action_space = self._generate_actions()
        self.observation_space = len(self.state)

    def _generate_actions(self):
        return [(l, t, h) for l in self.action_steps for t in self.action_steps for h in self.action_steps]

    def step(self, action_index):
        action = self.action_space[action_index]
        for i in range(3):
            self.state[i] += action[i]

        self.state[0] = np.clip(self.state[0], *self.light_range)
        self.state[1] = np.clip(self.state[1], *self.temp_range)
        self.state[2] = np.clip(self.state[2], *self.humidity_range)

        ppfd = self.state[0] * self.conversion
        T = self.state[1]
        water = self.water_supply
        humidity = self.state[2]

        growth = self._plant_growth_rate(self.M, ppfd, T, water, self.stage_factor,
                                         self.red_light, self.blue_light,
                                         self.gamma_base, self.rho_base, self.M_max)

        self.M += growth
        self.day += 1

        done = self.day >= self.max_days
        reward = growth

        return np.array(self.state, dtype=np.float32), reward, done, {}


    def reset(self):
        
        self.state = [
            np.random.randint(self.light_reset_range[0], self.light_reset_range[1] + 1),
            np.random.randint(self.temp_reset_range[0], self.temp_reset_range[1] + 1),
            np.random.randint(self.humidity_reset_range[0], self.humidity_reset_range[1] + 1)
        ]
        self.M = self.M0
        self.day = 0
        return np.array(self.state, dtype=np.float32)

        # ppfd , t , water , m , stage_factor , 
    def _plant_growth_rate(self, M, ppfd, T, water, stage_factor, red_light, blue_light, gamma_base, rho_base, M_max):
        light_factor = (ppfd / (ppfd + 1100)) * (0.7 * red_light + 0.5 * blue_light)
        temp_factor = np.exp(-0.1 * (T - 20) ** 2)
        r = gamma_base * light_factor * temp_factor * water * stage_factor
        respiration = rho_base * (1 + 0.3 * np.cos(ppfd / 1000)) * np.exp(-0.15 * (T - 22)**2)

        growth = (r * (M_max - M) * M / M_max) - respiration
        growth = max(growth, 0)
        return growth
# Out:
# /home/zaynap/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
env = LavenderGrowthEnv()

alpha = 0.1
gamma = 0.95
epsilon = 1.0
epsilon_decay = 0.999
min_epsilon = 0.05
num_episodes = 10000
max_steps = env.max_days  # = 90 days

def discretize_state(state):
    light_bin = int((state[0] - env.light_range[0]) / (env.light_range[1] - env.light_range[0]) * 10)
    temp_bin = int((state[1] - env.temp_range[0]) / (env.temp_range[1] - env.temp_range[0]) * 10)
    humid_bin = int((state[2] - env.humidity_range[0]) / (env.humidity_range[1] - env.humidity_range[0]) * 10)

    light_bin = np.clip(light_bin, 0, 10)
    temp_bin = np.clip(temp_bin, 0, 10)
    humid_bin = np.clip(humid_bin, 0, 10)

    return (light_bin, temp_bin, humid_bin)

state_bins = (11, 11, 11)
num_actions = len(env.action_space)
q_table = np.zeros(state_bins + (num_actions,))

def choose_action(state_idx):
    if random.uniform(0, 1) < epsilon:
        return random.randint(0, num_actions - 1)
    else:
        return np.argmax(q_table[state_idx])

# Training loop
for episode in range(num_episodes):
    state = env.reset()
    state_idx = discretize_state(state)
    done = False

    action = choose_action(state_idx)

    for step in range(max_steps):
        next_state, reward, done, _ = env.step(action)
        next_state_idx = discretize_state(next_state)
        next_action = choose_action(next_state_idx)

        old_value = q_table[state_idx + (action,)]
        next_q = q_table[next_state_idx + (next_action,)]
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_q)

        q_table[state_idx + (action,)] = new_value

        state_idx = next_state_idx
        action = next_action

        if done:
            break

    epsilon = max(min_epsilon, epsilon * epsilon_decay)

print("Training finished.")
# Out:
# Training finished.

# %%
state = env.reset()
state_idx = discretize_state(state)

# print("\nTesting trained agent:")
# total_reward = 0
# for step in range(env.max_days):
#     action = np.argmax(q_table[state_idx])
#     next_state, reward, done, _ = env.step(action)

#     print(f"Day {step+1}: Action={env.action_space[action]}, Reward={reward:.3f}, State={next_state}")
#     total_reward += reward
#     state_idx = discretize_state(next_state)

#     if done:
#         break

# print(f"\nTotal reward (final biomass gain): {total_reward:.2f}")


num_test_episodes = 5
all_rewards = []

for ep in range(num_test_episodes):
    state = env.reset()
    state_idx = discretize_state(state)
    episode_rewards = []

    for step in range(env.max_days):
        action = np.argmax(q_table[state_idx])
        next_state, reward, done, _ = env.step(action)
        print(f"episode {ep}, Day {step+1}: Action={env.action_space[action]}, Reward={reward:.3f}, State={next_state}")
        episode_rewards.append(reward)
        state_idx = discretize_state(next_state)

        if done:
            break

    all_rewards.append(episode_rewards)

# plotting 
plt.figure(figsize=(10, 6))
for i, rewards in enumerate(all_rewards):
    cumulative = np.cumsum(rewards)
    plt.plot(cumulative, label=f'Episode {i+1}')

plt.title('Lavender Growth Over Time (Biomass Accumulation) [SARSA]')
plt.xlabel('Day')
plt.ylabel('Cumulative Biomass Growth')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# episode 0, Day 1: Action=(-1, -2, 2), Reward=0.131, State=[9467.   24.   59.]
# episode 0, Day 2: Action=(2, -2, 0), Reward=0.501, State=[9469.   22.   59.]
# episode 0, Day 3: Action=(2, -2, -2), Reward=0.891, State=[9471.   20.   57.]
# episode 0, Day 4: Action=(0, 2, -2), Reward=0.655, State=[9471.   22.   55.]
# episode 0, Day 5: Action=(2, -2, -2), Reward=1.145, State=[9473.   20.   53.]
# episode 0, Day 6: Action=(0, 2, 0), Reward=0.853, State=[9473.   22.   53.]
# episode 0, Day 7: Action=(-2, -2, 0), Reward=1.473, State=[9471.   20.   53.]
# episode 0, Day 8: Action=(0, 2, 0), Reward=1.108, State=[9471.   22.   53.]
# episode 0, Day 9: Action=(-2, -2, 0), Reward=1.895, State=[9469.   20.   53.]
# episode 0, Day 10: Action=(0, 2, 0), Reward=1.437, State=[9469.   22.   53.]
# episode 0, Day 11: Action=(-2, -2, 0), Reward=2.439, State=[9467.   20.   53.]
# episode 0, Day 12: Action=(0, 2, 0), Reward=1.860, State=[9467.   22.   53.]
# episode 0, Day 13: Action=(-2, -2, 0), Reward=3.139, State=[9465.   20.   53.]
# episode 0, Day 14: Action=(0, 2, 0), Reward=2.405, State=[9465.   22.   53.]
# episode 0, Day 15: Action=(-2, -2, 0), Reward=4.038, State=[9463.   20.   53.]
# episode 0, Day 16: Action=(0, 2, 0), Reward=3.104, State=[9463.   22.   53.]
# episode 0, Day 17: Action=(-2, -2, 0), Reward=5.191, State=[9461.   20.   53.]
# episode 0, Day 18: Action=(0, 2, 0), Reward=3.999, State=[9461.   22.   53.]
# episode 0, Day 19: Action=(-2, -2, 0), Reward=6.667, State=[9459.   20.   53.]
# episode 0, Day 20: Action=(0, 2, 0), Reward=5.142, State=[9459.   22.   53.]
# episode 0, Day 21: Action=(-2, -2, 0), Reward=8.549, State=[9457.   20.   53.]
# episode 0, Day 22: Action=(0, 2, 0), Reward=6.597, State=[9457.   22.   53.]
# episode 0, Day 23: Action=(-2, -2, 0), Reward=10.940, State=[9455.   20.   53.]
# episode 0, Day 24: Action=(0, 2, 0), Reward=8.440, State=[9455.   22.   53.]
# episode 0, Day 25: Action=(-2, -2, 0), Reward=13.963, State=[9453.   20.   53.]
# episode 0, Day 26: Action=(0, 2, 0), Reward=10.762, State=[9453.   22.   53.]
# episode 0, Day 27: Action=(-2, -2, 0), Reward=17.758, State=[9451.   20.   53.]
# episode 0, Day 28: Action=(0, 2, 0), Reward=13.663, State=[9451.   22.   53.]
# episode 0, Day 29: Action=(-2, -2, 0), Reward=22.484, State=[9449.   20.   53.]
# episode 0, Day 30: Action=(0, 2, 0), Reward=17.254, State=[9449.   22.   53.]
# episode 0, Day 31: Action=(-2, -2, 0), Reward=28.304, State=[9447.   20.   53.]
# episode 0, Day 32: Action=(0, 2, 0), Reward=21.642, State=[9447.   22.   53.]
# episode 0, Day 33: Action=(-2, -2, 0), Reward=35.373, State=[9445.   20.   53.]
# episode 0, Day 34: Action=(0, 2, 0), Reward=26.918, State=[9445.   22.   53.]
# episode 0, Day 35: Action=(-2, -2, 0), Reward=43.804, State=[9443.   20.   53.]
# episode 0, Day 36: Action=(0, 2, 0), Reward=33.128, State=[9443.   22.   53.]
# episode 0, Day 37: Action=(-2, -2, 0), Reward=53.627, State=[9441.   20.   53.]
# episode 0, Day 38: Action=(0, 2, 0), Reward=40.243, State=[9441.   22.   53.]
# episode 0, Day 39: Action=(-2, -2, 0), Reward=64.733, State=[9439.   20.   53.]
# episode 0, Day 40: Action=(0, 2, 0), Reward=48.112, State=[9439.   22.   53.]
# episode 0, Day 41: Action=(-2, -2, 0), Reward=76.803, State=[9437.   20.   53.]
# episode 0, Day 42: Action=(0, 2, 0), Reward=56.419, State=[9437.   22.   53.]
# episode 0, Day 43: Action=(-2, -2, 0), Reward=89.254, State=[9435.   20.   53.]
# episode 0, Day 44: Action=(0, 2, 0), Reward=64.657, State=[9435.   22.   53.]
# episode 0, Day 45: Action=(-2, -2, 0), Reward=101.215, State=[9433.   20.   53.]
# episode 0, Day 46: Action=(0, 2, 0), Reward=72.138, State=[9433.   22.   53.]
# episode 0, Day 47: Action=(-2, -2, 0), Reward=111.578, State=[9431.   20.   53.]
# episode 0, Day 48: Action=(0, 2, 0), Reward=78.065, State=[9431.   22.   53.]
# episode 0, Day 49: Action=(-2, -2, 0), Reward=119.144, State=[9429.   20.   53.]
# episode 0, Day 50: Action=(0, 2, 0), Reward=81.669, State=[9429.   22.   53.]
# episode 0, Day 51: Action=(-2, -2, 0), Reward=122.862, State=[9427.   20.   53.]
# episode 0, Day 52: Action=(0, 2, 0), Reward=82.390, State=[9427.   22.   53.]
# episode 0, Day 53: Action=(-2, -2, 0), Reward=122.100, State=[9425.   20.   53.]
# episode 0, Day 54: Action=(0, 2, 0), Reward=80.044, State=[9425.   22.   53.]
# episode 0, Day 55: Action=(-2, -2, 0), Reward=116.843, State=[9423.   20.   53.]
# episode 0, Day 56: Action=(0, 2, 0), Reward=74.886, State=[9423.   22.   53.]
# episode 0, Day 57: Action=(-2, -2, 0), Reward=107.726, State=[9421.   20.   53.]
# episode 0, Day 58: Action=(0, 2, 0), Reward=67.561, State=[9421.   22.   53.]
# episode 0, Day 59: Action=(-2, -2, 0), Reward=95.873, State=[9419.   20.   53.]
# episode 0, Day 60: Action=(0, 2, 0), Reward=58.933, State=[9419.   22.   53.]
# episode 0, Day 61: Action=(-2, -2, 0), Reward=82.612, State=[9417.   20.   53.]
# episode 0, Day 62: Action=(0, 2, 0), Reward=49.879, State=[9417.   22.   53.]
# episode 0, Day 63: Action=(-2, -2, 0), Reward=69.183, State=[9415.   20.   53.]
# episode 0, Day 64: Action=(0, 2, 0), Reward=41.128, State=[9415.   22.   53.]
# episode 0, Day 65: Action=(-2, -2, 0), Reward=56.541, State=[9413.   20.   53.]
# episode 0, Day 66: Action=(0, 2, 0), Reward=33.174, State=[9413.   22.   53.]
# episode 0, Day 67: Action=(-2, -2, 0), Reward=45.279, State=[9411.   20.   53.]
# episode 0, Day 68: Action=(0, 2, 0), Reward=26.280, State=[9411.   22.   53.]
# episode 0, Day 69: Action=(-2, -2, 0), Reward=35.668, State=[9409.   20.   53.]
# episode 0, Day 70: Action=(0, 2, 0), Reward=20.519, State=[9409.   22.   53.]
# episode 0, Day 71: Action=(-2, -2, 0), Reward=27.730, State=[9407.   20.   53.]
# episode 0, Day 72: Action=(0, 2, 0), Reward=15.838, State=[9407.   22.   53.]
# episode 0, Day 73: Action=(-2, -2, 0), Reward=21.339, State=[9405.   20.   53.]
# episode 0, Day 74: Action=(0, 2, 0), Reward=12.116, State=[9405.   22.   53.]
# episode 0, Day 75: Action=(-2, -2, 0), Reward=16.291, State=[9403.   20.   53.]
# episode 0, Day 76: Action=(0, 2, 0), Reward=9.204, State=[9403.   22.   53.]
# episode 0, Day 77: Action=(-2, -2, 0), Reward=12.364, State=[9401.   20.   53.]
# episode 0, Day 78: Action=(0, 2, 0), Reward=6.954, State=[9401.   22.   53.]
# episode 0, Day 79: Action=(-2, -2, 0), Reward=9.341, State=[9399.   20.   53.]
# episode 0, Day 80: Action=(0, 2, 0), Reward=5.231, State=[9399.   22.   53.]
# episode 0, Day 81: Action=(-2, -2, 0), Reward=7.034, State=[9397.   20.   53.]
# episode 0, Day 82: Action=(0, 2, 0), Reward=3.923, State=[9397.   22.   53.]
# episode 0, Day 83: Action=(-2, -2, 0), Reward=5.284, State=[9395.   20.   53.]
# episode 0, Day 84: Action=(0, 2, 0), Reward=2.933, State=[9395.   22.   53.]
# episode 0, Day 85: Action=(-2, -2, 0), Reward=3.964, State=[9393.   20.   53.]
# episode 0, Day 86: Action=(0, 2, 0), Reward=2.188, State=[9393.   22.   53.]
# episode 0, Day 87: Action=(-2, -2, 0), Reward=2.971, State=[9391.   20.   53.]
# episode 0, Day 88: Action=(0, 2, 0), Reward=1.628, State=[9391.   22.   53.]
# episode 0, Day 89: Action=(-2, -2, 0), Reward=2.226, State=[9389.   20.   53.]
# episode 0, Day 90: Action=(0, 2, 0), Reward=1.209, State=[9389.   22.   53.]
# episode 1, Day 1: Action=(-1, -2, 0), Reward=0.125, State=[9091.   24.   53.]
# episode 1, Day 2: Action=(0, -2, -1), Reward=0.481, State=[9091.   22.   52.]
# episode 1, Day 3: Action=(-2, -2, 0), Reward=0.855, State=[9089.   20.   52.]
# episode 1, Day 4: Action=(0, 2, 0), Reward=0.623, State=[9089.   22.   52.]
# episode 1, Day 5: Action=(-2, -2, 0), Reward=1.089, State=[9087.   20.   52.]
# episode 1, Day 6: Action=(0, 2, 0), Reward=0.804, State=[9087.   22.   52.]
# episode 1, Day 7: Action=(-2, -2, 0), Reward=1.388, State=[9085.   20.   52.]
# episode 1, Day 8: Action=(0, 2, 0), Reward=1.036, State=[9085.   22.   52.]
# episode 1, Day 9: Action=(-2, -2, 0), Reward=1.770, State=[9083.   20.   52.]
# episode 1, Day 10: Action=(0, 2, 0), Reward=1.333, State=[9083.   22.   52.]
# episode 1, Day 11: Action=(-2, -2, 0), Reward=2.259, State=[9081.   20.   52.]
# episode 1, Day 12: Action=(0, 2, 0), Reward=1.712, State=[9081.   22.   52.]
# episode 1, Day 13: Action=(-2, -2, 0), Reward=2.883, State=[9079.   20.   52.]
# episode 1, Day 14: Action=(0, 2, 0), Reward=2.195, State=[9079.   22.   52.]
# episode 1, Day 15: Action=(-2, -2, 0), Reward=3.678, State=[9077.   20.   52.]
# episode 1, Day 16: Action=(0, 2, 0), Reward=2.810, State=[9077.   22.   52.]
# episode 1, Day 17: Action=(-2, -2, 0), Reward=4.690, State=[9075.   20.   52.]
# episode 1, Day 18: Action=(0, 2, 0), Reward=3.592, State=[9075.   22.   52.]
# episode 1, Day 19: Action=(-2, -2, 0), Reward=5.975, State=[9073.   20.   52.]
# episode 1, Day 20: Action=(0, 2, 0), Reward=4.583, State=[9073.   22.   52.]
# episode 1, Day 21: Action=(-2, -2, 0), Reward=7.602, State=[9071.   20.   52.]
# episode 1, Day 22: Action=(0, 2, 0), Reward=5.836, State=[9071.   22.   52.]
# episode 1, Day 23: Action=(-2, -2, 0), Reward=9.655, State=[9069.   20.   52.]
# episode 1, Day 24: Action=(0, 2, 0), Reward=7.413, State=[9069.   22.   52.]
# episode 1, Day 25: Action=(-2, -2, 0), Reward=12.236, State=[9067.   20.   52.]
# episode 1, Day 26: Action=(0, 2, 0), Reward=9.389, State=[9067.   22.   52.]
# episode 1, Day 27: Action=(-2, -2, 0), Reward=15.460, State=[9065.   20.   52.]
# episode 1, Day 28: Action=(0, 2, 0), Reward=11.848, State=[9065.   22.   52.]
# episode 1, Day 29: Action=(-2, -2, 0), Reward=19.459, State=[9063.   20.   52.]
# episode 1, Day 30: Action=(0, 2, 0), Reward=14.883, State=[9063.   22.   52.]
# episode 1, Day 31: Action=(-2, -2, 0), Reward=24.377, State=[9061.   20.   52.]
# episode 1, Day 32: Action=(0, 2, 0), Reward=18.590, State=[9061.   22.   52.]
# episode 1, Day 33: Action=(-2, -2, 0), Reward=30.352, State=[9059.   20.   52.]
# episode 1, Day 34: Action=(0, 2, 0), Reward=23.057, State=[9059.   22.   52.]
# episode 1, Day 35: Action=(-2, -2, 0), Reward=37.506, State=[9057.   20.   52.]
# episode 1, Day 36: Action=(0, 2, 0), Reward=28.349, State=[9057.   22.   52.]
# episode 1, Day 37: Action=(-2, -2, 0), Reward=45.910, State=[9055.   20.   52.]
# episode 1, Day 38: Action=(0, 2, 0), Reward=34.482, State=[9055.   22.   52.]
# episode 1, Day 39: Action=(-2, -2, 0), Reward=55.546, State=[9053.   20.   52.]
# episode 1, Day 40: Action=(0, 2, 0), Reward=41.392, State=[9053.   22.   52.]
# episode 1, Day 41: Action=(-2, -2, 0), Reward=66.255, State=[9051.   20.   52.]
# episode 1, Day 42: Action=(0, 2, 0), Reward=48.899, State=[9051.   22.   52.]
# episode 1, Day 43: Action=(-2, -2, 0), Reward=77.682, State=[9049.   20.   52.]
# episode 1, Day 44: Action=(0, 2, 0), Reward=56.674, State=[9049.   22.   52.]
# episode 1, Day 45: Action=(-2, -2, 0), Reward=89.242, State=[9047.   20.   52.]
# episode 1, Day 46: Action=(0, 2, 0), Reward=64.227, State=[9047.   22.   52.]
# episode 1, Day 47: Action=(-2, -2, 0), Reward=100.111, State=[9045.   20.   52.]
# episode 1, Day 48: Action=(0, 2, 0), Reward=70.927, State=[9045.   22.   52.]
# episode 1, Day 49: Action=(-2, -2, 0), Reward=109.291, State=[9043.   20.   52.]
# episode 1, Day 50: Action=(0, 2, 0), Reward=76.075, State=[9043.   22.   52.]
# episode 1, Day 51: Action=(-2, -2, 0), Reward=115.750, State=[9041.   20.   52.]
# episode 1, Day 52: Action=(0, 2, 0), Reward=79.028, State=[9041.   22.   52.]
# episode 1, Day 53: Action=(-2, -2, 0), Reward=118.627, State=[9039.   20.   52.]
# episode 1, Day 54: Action=(0, 2, 0), Reward=79.346, State=[9039.   22.   52.]
# episode 1, Day 55: Action=(-2, -2, 0), Reward=117.448, State=[9037.   20.   52.]
# episode 1, Day 56: Action=(0, 2, 0), Reward=76.916, State=[9037.   22.   52.]
# episode 1, Day 57: Action=(-2, -2, 0), Reward=112.266, State=[9035.   20.   52.]
# episode 1, Day 58: Action=(0, 2, 0), Reward=71.998, State=[9035.   22.   52.]
# episode 1, Day 59: Action=(-2, -2, 0), Reward=103.674, State=[9033.   20.   52.]
# episode 1, Day 60: Action=(0, 2, 0), Reward=65.166, State=[9033.   22.   52.]
# episode 1, Day 61: Action=(-2, -2, 0), Reward=92.658, State=[9031.   20.   52.]
# episode 1, Day 62: Action=(0, 2, 0), Reward=57.168, State=[9031.   22.   52.]
# episode 1, Day 63: Action=(-2, -2, 0), Reward=80.366, State=[9029.   20.   52.]
# episode 1, Day 64: Action=(0, 2, 0), Reward=48.763, State=[9029.   22.   52.]
# episode 1, Day 65: Action=(-2, -2, 0), Reward=67.876, State=[9027.   20.   52.]
# episode 1, Day 66: Action=(0, 2, 0), Reward=40.589, State=[9027.   22.   52.]
# episode 1, Day 67: Action=(-2, -2, 0), Reward=56.027, State=[9025.   20.   52.]
# episode 1, Day 68: Action=(0, 2, 0), Reward=33.092, State=[9025.   22.   52.]
# episode 1, Day 69: Action=(-2, -2, 0), Reward=45.366, State=[9023.   20.   52.]
# episode 1, Day 70: Action=(0, 2, 0), Reward=26.519, State=[9023.   22.   52.]
# episode 1, Day 71: Action=(-2, -2, 0), Reward=36.158, State=[9021.   20.   52.]
# episode 1, Day 72: Action=(0, 2, 0), Reward=20.957, State=[9021.   22.   52.]
# episode 1, Day 73: Action=(-2, -2, 0), Reward=28.456, State=[9019.   20.   52.]
# episode 1, Day 74: Action=(0, 2, 0), Reward=16.377, State=[9019.   22.   52.]
# episode 1, Day 75: Action=(-2, -2, 0), Reward=22.170, State=[9017.   20.   52.]
# episode 1, Day 76: Action=(0, 2, 0), Reward=12.686, State=[9017.   22.   52.]
# episode 1, Day 77: Action=(-2, -2, 0), Reward=17.137, State=[9015.   20.   52.]
# episode 1, Day 78: Action=(0, 2, 0), Reward=9.758, State=[9015.   22.   52.]
# episode 1, Day 79: Action=(-2, -2, 0), Reward=13.168, State=[9013.   20.   52.]
# episode 1, Day 80: Action=(0, 2, 0), Reward=7.465, State=[9013.   22.   52.]
# episode 1, Day 81: Action=(-2, -2, 0), Reward=10.071, State=[9011.   20.   52.]
# episode 1, Day 82: Action=(0, 2, 0), Reward=5.687, State=[9011.   22.   52.]
# episode 1, Day 83: Action=(-2, -2, 0), Reward=7.677, State=[9009.   20.   52.]
# episode 1, Day 84: Action=(0, 2, 0), Reward=4.317, State=[9009.   22.   52.]
# episode 1, Day 85: Action=(-2, -2, 0), Reward=5.837, State=[9007.   20.   52.]
# episode 1, Day 86: Action=(0, 2, 0), Reward=3.268, State=[9007.   22.   52.]
# episode 1, Day 87: Action=(-2, -2, 0), Reward=4.430, State=[9005.   20.   52.]
# episode 1, Day 88: Action=(0, 2, 0), Reward=2.468, State=[9005.   22.   52.]
# episode 1, Day 89: Action=(-2, -2, 0), Reward=3.359, State=[9003.   20.   52.]
# episode 1, Day 90: Action=(0, 2, 0), Reward=1.860, State=[9003.   22.   52.]
# episode 2, Day 1: Action=(-2, -2, -2), Reward=0.049, State=[9109.   25.   54.]
# episode 2, Day 2: Action=(-1, -2, 0), Reward=0.271, State=[9108.   23.   54.]
# episode 2, Day 3: Action=(0, -2, -1), Reward=0.710, State=[9108.   21.   53.]
# episode 2, Day 4: Action=(-2, -2, 0), Reward=0.851, State=[9106.   19.   53.]
# episode 2, Day 5: Action=(0, 2, 0), Reward=0.934, State=[9106.   21.   53.]
# episode 2, Day 6: Action=(-2, -2, 0), Reward=1.107, State=[9104.   19.   53.]
# episode 2, Day 7: Action=(0, 2, 0), Reward=1.227, State=[9104.   21.   53.]
# episode 2, Day 8: Action=(-2, -2, 0), Reward=1.441, State=[9102.   19.   53.]
# episode 2, Day 9: Action=(0, 2, 0), Reward=1.608, State=[9102.   21.   53.]
# episode 2, Day 10: Action=(-2, -2, 0), Reward=1.877, State=[9100.   19.   53.]
# episode 2, Day 11: Action=(0, 2, 0), Reward=2.106, State=[9100.   21.   53.]
# episode 2, Day 12: Action=(-2, -2, 0), Reward=2.445, State=[9098.   19.   53.]
# episode 2, Day 13: Action=(0, 2, 0), Reward=2.754, State=[9098.   21.   53.]
# episode 2, Day 14: Action=(-2, -2, 0), Reward=3.183, State=[9096.   19.   53.]
# episode 2, Day 15: Action=(0, 2, 0), Reward=3.595, State=[9096.   21.   53.]
# episode 2, Day 16: Action=(-2, -2, 0), Reward=4.142, State=[9094.   19.   53.]
# episode 2, Day 17: Action=(0, 2, 0), Reward=4.687, State=[9094.   21.   53.]
# episode 2, Day 18: Action=(-2, -2, 0), Reward=5.384, State=[9092.   19.   53.]
# episode 2, Day 19: Action=(0, 2, 0), Reward=6.100, State=[9092.   21.   53.]
# episode 2, Day 20: Action=(-2, -2, 0), Reward=6.989, State=[9090.   19.   53.]
# episode 2, Day 21: Action=(0, 2, 0), Reward=7.920, State=[9090.   21.   53.]
# episode 2, Day 22: Action=(-2, -2, 0), Reward=9.052, State=[9088.   19.   53.]
# episode 2, Day 23: Action=(0, 2, 0), Reward=10.256, State=[9088.   21.   53.]
# episode 2, Day 24: Action=(-2, -2, 0), Reward=11.692, State=[9086.   19.   53.]
# episode 2, Day 25: Action=(0, 2, 0), Reward=13.236, State=[9086.   21.   53.]
# episode 2, Day 26: Action=(-2, -2, 0), Reward=15.047, State=[9084.   19.   53.]
# episode 2, Day 27: Action=(0, 2, 0), Reward=17.006, State=[9084.   21.   53.]
# episode 2, Day 28: Action=(-2, -2, 0), Reward=19.273, State=[9082.   19.   53.]
# episode 2, Day 29: Action=(0, 2, 0), Reward=21.729, State=[9082.   21.   53.]
# episode 2, Day 30: Action=(-2, -2, 0), Reward=24.533, State=[9080.   19.   53.]
# episode 2, Day 31: Action=(0, 2, 0), Reward=27.567, State=[9080.   21.   53.]
# episode 2, Day 32: Action=(-2, -2, 0), Reward=30.984, State=[9078.   19.   53.]
# episode 2, Day 33: Action=(0, 2, 0), Reward=34.661, State=[9078.   21.   53.]
# episode 2, Day 34: Action=(-2, -2, 0), Reward=38.740, State=[9076.   19.   53.]
# episode 2, Day 35: Action=(0, 2, 0), Reward=43.087, State=[9076.   21.   53.]
# episode 2, Day 36: Action=(-2, -2, 0), Reward=47.827, State=[9074.   19.   53.]
# episode 2, Day 37: Action=(0, 2, 0), Reward=52.806, State=[9074.   21.   53.]
# episode 2, Day 38: Action=(-2, -2, 0), Reward=58.121, State=[9072.   19.   53.]
# episode 2, Day 39: Action=(0, 2, 0), Reward=63.590, State=[9072.   21.   53.]
# episode 2, Day 40: Action=(-2, -2, 0), Reward=69.272, State=[9070.   19.   53.]
# episode 2, Day 41: Action=(0, 2, 0), Reward=74.952, State=[9070.   21.   53.]
# episode 2, Day 42: Action=(-2, -2, 0), Reward=80.646, State=[9068.   19.   53.]
# episode 2, Day 43: Action=(0, 2, 0), Reward=86.106, State=[9068.   21.   53.]
# episode 2, Day 44: Action=(-2, -2, 0), Reward=91.311, State=[9066.   19.   53.]
# episode 2, Day 45: Action=(0, 2, 0), Reward=95.993, State=[9066.   21.   53.]
# episode 2, Day 46: Action=(-2, -2, 0), Reward=100.114, State=[9064.   19.   53.]
# episode 2, Day 47: Action=(0, 2, 0), Reward=103.412, State=[9064.   21.   53.]
# episode 2, Day 48: Action=(-2, -2, 0), Reward=105.869, State=[9062.   19.   53.]
# episode 2, Day 49: Action=(0, 2, 0), Reward=107.266, State=[9062.   21.   53.]
# episode 2, Day 50: Action=(-2, -2, 0), Reward=107.645, State=[9060.   19.   53.]
# episode 2, Day 51: Action=(0, 2, 0), Reward=106.860, State=[9060.   21.   53.]
# episode 2, Day 52: Action=(-2, -2, 0), Reward=105.042, State=[9058.   19.   53.]
# episode 2, Day 53: Action=(0, 2, 0), Reward=102.133, State=[9058.   21.   53.]
# episode 2, Day 54: Action=(-2, -2, 0), Reward=98.350, State=[9056.   19.   53.]
# episode 2, Day 55: Action=(0, 2, 0), Reward=93.706, State=[9056.   21.   53.]
# episode 2, Day 56: Action=(-2, -2, 0), Reward=88.479, State=[9054.   19.   53.]
# episode 2, Day 57: Action=(0, 2, 0), Reward=82.714, State=[9054.   21.   53.]
# episode 2, Day 58: Action=(-2, -2, 0), Reward=76.709, State=[9052.   19.   53.]
# episode 2, Day 59: Action=(0, 2, 0), Reward=70.494, State=[9052.   21.   53.]
# episode 2, Day 60: Action=(-2, -2, 0), Reward=64.349, State=[9050.   19.   53.]
# episode 2, Day 61: Action=(0, 2, 0), Reward=58.262, State=[9050.   21.   53.]
# episode 2, Day 62: Action=(-2, -2, 0), Reward=52.474, State=[9048.   19.   53.]
# episode 2, Day 63: Action=(0, 2, 0), Reward=46.919, State=[9048.   21.   53.]
# episode 2, Day 64: Action=(-2, -2, 0), Reward=41.795, State=[9046.   19.   53.]
# episode 2, Day 65: Action=(0, 2, 0), Reward=36.988, State=[9046.   21.   53.]
# episode 2, Day 66: Action=(-2, -2, 0), Reward=32.661, State=[9044.   19.   53.]
# episode 2, Day 67: Action=(0, 2, 0), Reward=28.665, State=[9044.   21.   53.]
# episode 2, Day 68: Action=(-2, -2, 0), Reward=25.142, State=[9042.   19.   53.]
# episode 2, Day 69: Action=(0, 2, 0), Reward=21.920, State=[9042.   21.   53.]
# episode 2, Day 70: Action=(-2, -2, 0), Reward=19.130, State=[9040.   19.   53.]
# episode 2, Day 71: Action=(0, 2, 0), Reward=16.588, State=[9040.   21.   53.]
# episode 2, Day 72: Action=(-2, -2, 0), Reward=14.426, State=[9038.   19.   53.]
# episode 2, Day 73: Action=(0, 2, 0), Reward=12.454, State=[9038.   21.   53.]
# episode 2, Day 74: Action=(-2, -2, 0), Reward=10.807, State=[9036.   19.   53.]
# episode 2, Day 75: Action=(0, 2, 0), Reward=9.294, State=[9036.   21.   53.]
# episode 2, Day 76: Action=(-2, -2, 0), Reward=8.055, State=[9034.   19.   53.]
# episode 2, Day 77: Action=(0, 2, 0), Reward=6.904, State=[9034.   21.   53.]
# episode 2, Day 78: Action=(-2, -2, 0), Reward=5.983, State=[9032.   19.   53.]
# episode 2, Day 79: Action=(0, 2, 0), Reward=5.110, State=[9032.   21.   53.]
# episode 2, Day 80: Action=(-2, -2, 0), Reward=4.433, State=[9030.   19.   53.]
# episode 2, Day 81: Action=(0, 2, 0), Reward=3.772, State=[9030.   21.   53.]
# episode 2, Day 82: Action=(-2, -2, 0), Reward=3.279, State=[9028.   19.   53.]
# episode 2, Day 83: Action=(0, 2, 0), Reward=2.778, State=[9028.   21.   53.]
# episode 2, Day 84: Action=(-2, -2, 0), Reward=2.424, State=[9026.   19.   53.]
# episode 2, Day 85: Action=(0, 2, 0), Reward=2.041, State=[9026.   21.   53.]
# episode 2, Day 86: Action=(-2, -2, 0), Reward=1.791, State=[9024.   19.   53.]
# episode 2, Day 87: Action=(0, 2, 0), Reward=1.497, State=[9024.   21.   53.]
# episode 2, Day 88: Action=(-2, -2, 0), Reward=1.323, State=[9022.   19.   53.]
# episode 2, Day 89: Action=(0, 2, 0), Reward=1.096, State=[9022.   21.   53.]
# episode 2, Day 90: Action=(-2, -2, 0), Reward=0.979, State=[9020.   19.   53.]
# episode 3, Day 1: Action=(-1, -2, 2), Reward=0.263, State=[8959.   23.   61.]
# episode 3, Day 2: Action=(-2, -1, 2), Reward=0.488, State=[8957.   22.   63.]
# episode 3, Day 3: Action=(-2, -1, 1), Reward=0.760, State=[8955.   21.   64.]
# episode 3, Day 4: Action=(-2, -1, 1), Reward=0.985, State=[8953.   20.   65.]
# episode 3, Day 5: Action=(-1, 0, 2), Reward=1.139, State=[8952.   20.   67.]
# episode 3, Day 6: Action=(-1, 0, 2), Reward=1.316, State=[8951.   20.   69.]
# episode 3, Day 7: Action=(-1, 0, 2), Reward=1.522, State=[8950.   20.   71.]
# episode 3, Day 8: Action=(1, 1, -2), Reward=1.568, State=[8951.   21.   69.]
# episode 3, Day 9: Action=(-2, -1, -2), Reward=2.003, State=[8949.   20.   67.]
# episode 3, Day 10: Action=(-1, 0, 2), Reward=2.314, State=[8948.   20.   69.]
# episode 3, Day 11: Action=(-1, 0, 2), Reward=2.673, State=[8947.   20.   71.]
# episode 3, Day 12: Action=(1, 1, -2), Reward=2.770, State=[8948.   21.   69.]
# episode 3, Day 13: Action=(-2, -1, -2), Reward=3.516, State=[8946.   20.   67.]
# episode 3, Day 14: Action=(-1, 0, 2), Reward=4.058, State=[8945.   20.   69.]
# episode 3, Day 15: Action=(-1, 0, 2), Reward=4.682, State=[8944.   20.   71.]
# episode 3, Day 16: Action=(1, 1, -2), Reward=4.864, State=[8945.   21.   69.]
# episode 3, Day 17: Action=(-2, -1, -2), Reward=6.144, State=[8943.   20.   67.]
# episode 3, Day 18: Action=(-1, 0, 2), Reward=7.080, State=[8942.   20.   69.]
# episode 3, Day 19: Action=(-1, 0, 2), Reward=8.153, State=[8941.   20.   71.]
# episode 3, Day 20: Action=(1, 1, -2), Reward=8.467, State=[8942.   21.   69.]
# episode 3, Day 21: Action=(-2, -1, -2), Reward=10.652, State=[8940.   20.   67.]
# episode 3, Day 22: Action=(-1, 0, 2), Reward=12.238, State=[8939.   20.   69.]
# episode 3, Day 23: Action=(-1, 0, 2), Reward=14.045, State=[8938.   20.   71.]
# episode 3, Day 24: Action=(1, 1, -2), Reward=14.547, State=[8939.   21.   69.]
# episode 3, Day 25: Action=(-2, -1, -2), Reward=18.207, State=[8937.   20.   67.]
# episode 3, Day 26: Action=(-1, 0, 2), Reward=20.812, State=[8936.   20.   69.]
# episode 3, Day 27: Action=(-1, 0, 2), Reward=23.747, State=[8935.   20.   71.]
# episode 3, Day 28: Action=(1, 1, -2), Reward=24.447, State=[8936.   21.   69.]
# episode 3, Day 29: Action=(-2, -1, -2), Reward=30.370, State=[8934.   20.   67.]
# episode 3, Day 30: Action=(-1, 0, 2), Reward=34.418, State=[8933.   20.   69.]
# episode 3, Day 31: Action=(-1, 0, 2), Reward=38.888, State=[8932.   20.   71.]
# episode 3, Day 32: Action=(1, 1, -2), Reward=39.606, State=[8933.   21.   69.]
# episode 3, Day 33: Action=(-2, -1, -2), Reward=48.622, State=[8931.   20.   67.]
# episode 3, Day 34: Action=(-1, 0, 2), Reward=54.325, State=[8930.   20.   69.]
# episode 3, Day 35: Action=(-1, 0, 2), Reward=60.406, State=[8929.   20.   71.]
# episode 3, Day 36: Action=(1, 1, -2), Reward=60.435, State=[8930.   21.   69.]
# episode 3, Day 37: Action=(-2, -1, -2), Reward=72.830, State=[8928.   20.   67.]
# episode 3, Day 38: Action=(-1, 0, 2), Reward=79.577, State=[8927.   20.   69.]
# episode 3, Day 39: Action=(-1, 0, 2), Reward=86.315, State=[8926.   20.   71.]
# episode 3, Day 40: Action=(1, 1, -2), Reward=84.030, State=[8927.   21.   69.]
# episode 3, Day 41: Action=(-2, -1, -2), Reward=98.524, State=[8925.   20.   67.]
# episode 3, Day 42: Action=(-1, 0, 2), Reward=104.197, State=[8924.   20.   69.]
# episode 3, Day 43: Action=(-1, 0, 2), Reward=109.093, State=[8923.   20.   71.]
# episode 3, Day 44: Action=(1, 1, -2), Reward=102.247, State=[8924.   21.   69.]
# episode 3, Day 45: Action=(-2, -1, -2), Reward=115.553, State=[8922.   20.   67.]
# episode 3, Day 46: Action=(-1, 0, 2), Reward=117.108, State=[8921.   20.   69.]
# episode 3, Day 47: Action=(-1, 0, 2), Reward=117.262, State=[8920.   20.   71.]
# episode 3, Day 48: Action=(1, 1, -2), Reward=104.943, State=[8921.   21.   69.]
# episode 3, Day 49: Action=(-2, -1, -2), Reward=113.631, State=[8919.   20.   67.]
# episode 3, Day 50: Action=(-1, 0, 2), Reward=109.779, State=[8918.   20.   69.]
# episode 3, Day 51: Action=(-1, 0, 2), Reward=104.778, State=[8917.   20.   71.]
# episode 3, Day 52: Action=(1, 1, -2), Reward=89.421, State=[8918.   21.   69.]
# episode 3, Day 53: Action=(-2, -1, -2), Reward=92.861, State=[8916.   20.   67.]
# episode 3, Day 54: Action=(-1, 0, 2), Reward=85.769, State=[8915.   20.   69.]
# episode 3, Day 55: Action=(-1, 0, 2), Reward=78.420, State=[8914.   20.   71.]
# episode 3, Day 56: Action=(1, 1, -2), Reward=64.260, State=[8915.   21.   69.]
# episode 3, Day 57: Action=(-2, -1, -2), Reward=64.503, State=[8913.   20.   67.]
# episode 3, Day 58: Action=(-1, 0, 2), Reward=57.513, State=[8912.   20.   69.]
# episode 3, Day 59: Action=(-1, 0, 2), Reward=50.914, State=[8911.   20.   71.]
# episode 3, Day 60: Action=(1, 1, -2), Reward=40.508, State=[8912.   21.   69.]
# episode 3, Day 61: Action=(-2, -1, -2), Reward=39.721, State=[8910.   20.   67.]
# episode 3, Day 62: Action=(-1, 0, 2), Reward=34.585, State=[8909.   20.   69.]
# episode 3, Day 63: Action=(-1, 0, 2), Reward=29.979, State=[8908.   20.   71.]
# episode 3, Day 64: Action=(1, 1, -2), Reward=23.404, State=[8909.   21.   69.]
# episode 3, Day 65: Action=(-2, -1, -2), Reward=22.629, State=[8907.   20.   67.]
# episode 3, Day 66: Action=(-1, 0, 2), Reward=19.423, State=[8906.   20.   69.]
# episode 3, Day 67: Action=(-1, 0, 2), Reward=16.629, State=[8905.   20.   71.]
# episode 3, Day 68: Action=(1, 1, -2), Reward=12.832, State=[8906.   21.   69.]
# episode 3, Day 69: Action=(-2, -1, -2), Reward=12.317, State=[8904.   20.   67.]
# episode 3, Day 70: Action=(-1, 0, 2), Reward=10.487, State=[8903.   20.   69.]
# episode 3, Day 71: Action=(-1, 0, 2), Reward=8.917, State=[8902.   20.   71.]
# episode 3, Day 72: Action=(1, 1, -2), Reward=6.830, State=[8903.   21.   69.]
# episode 3, Day 73: Action=(-2, -1, -2), Reward=6.539, State=[8901.   20.   67.]
# episode 3, Day 74: Action=(-1, 0, 2), Reward=5.543, State=[8900.   20.   69.]
# episode 3, Day 75: Action=(-1, 0, 2), Reward=4.696, State=[8899.   20.   71.]
# episode 3, Day 76: Action=(1, 1, -2), Reward=3.575, State=[8900.   21.   69.]
# episode 3, Day 77: Action=(-2, -1, -2), Reward=3.426, State=[8898.   20.   67.]
# episode 3, Day 78: Action=(-1, 0, 2), Reward=2.898, State=[8897.   20.   69.]
# episode 3, Day 79: Action=(-1, 0, 2), Reward=2.451, State=[8896.   20.   71.]
# episode 3, Day 80: Action=(1, 1, -2), Reward=1.851, State=[8897.   21.   69.]
# episode 3, Day 81: Action=(-2, -1, -2), Reward=1.785, State=[8895.   20.   67.]
# episode 3, Day 82: Action=(-1, 0, 2), Reward=1.508, State=[8894.   20.   69.]
# episode 3, Day 83: Action=(-1, 0, 2), Reward=1.274, State=[8893.   20.   71.]
# episode 3, Day 84: Action=(1, 1, -2), Reward=0.950, State=[8894.   21.   69.]
# episode 3, Day 85: Action=(-2, -1, -2), Reward=0.928, State=[8892.   20.   67.]
# episode 3, Day 86: Action=(-1, 0, 2), Reward=0.784, State=[8891.   20.   69.]
# episode 3, Day 87: Action=(-1, 0, 2), Reward=0.662, State=[8890.   20.   71.]
# episode 3, Day 88: Action=(1, 1, -2), Reward=0.482, State=[8891.   21.   69.]
# episode 3, Day 89: Action=(-2, -1, -2), Reward=0.484, State=[8889.   20.   67.]
# episode 3, Day 90: Action=(-1, 0, 2), Reward=0.408, State=[8888.   20.   69.]
# episode 4, Day 1: Action=(2, -2, -1), Reward=0.048, State=[9091.   25.   59.]
# episode 4, Day 2: Action=(-1, -2, 2), Reward=0.270, State=[9090.   23.   61.]
# episode 4, Day 3: Action=(-2, -1, 2), Reward=0.501, State=[9088.   22.   63.]
# episode 4, Day 4: Action=(-2, -1, 1), Reward=0.780, State=[9086.   21.   64.]
# episode 4, Day 5: Action=(-2, -1, 1), Reward=1.012, State=[9084.   20.   65.]
# episode 4, Day 6: Action=(-1, 0, 2), Reward=1.172, State=[9083.   20.   67.]
# episode 4, Day 7: Action=(-1, 0, 2), Reward=1.357, State=[9082.   20.   69.]
# episode 4, Day 8: Action=(-1, 0, 2), Reward=1.571, State=[9081.   20.   71.]
# episode 4, Day 9: Action=(1, 1, -2), Reward=1.623, State=[9082.   21.   69.]
# episode 4, Day 10: Action=(-2, -1, -2), Reward=2.075, State=[9080.   20.   67.]
# episode 4, Day 11: Action=(-1, 0, 2), Reward=2.401, State=[9079.   20.   69.]
# episode 4, Day 12: Action=(-1, 0, 2), Reward=2.779, State=[9078.   20.   71.]
# episode 4, Day 13: Action=(1, 1, -2), Reward=2.885, State=[9079.   21.   69.]
# episode 4, Day 14: Action=(-2, -1, -2), Reward=3.666, State=[9077.   20.   67.]
# episode 4, Day 15: Action=(-1, 0, 2), Reward=4.239, State=[9076.   20.   69.]
# episode 4, Day 16: Action=(-1, 0, 2), Reward=4.899, State=[9075.   20.   71.]
# episode 4, Day 17: Action=(1, 1, -2), Reward=5.098, State=[9076.   21.   69.]
# episode 4, Day 18: Action=(-2, -1, -2), Reward=6.448, State=[9074.   20.   67.]
# episode 4, Day 19: Action=(-1, 0, 2), Reward=7.441, State=[9073.   20.   69.]
# episode 4, Day 20: Action=(-1, 0, 2), Reward=8.582, State=[9072.   20.   71.]
# episode 4, Day 21: Action=(1, 1, -2), Reward=8.927, State=[9073.   21.   69.]
# episode 4, Day 22: Action=(-2, -1, -2), Reward=11.243, State=[9071.   20.   67.]
# episode 4, Day 23: Action=(-1, 0, 2), Reward=12.935, State=[9070.   20.   69.]
# episode 4, Day 24: Action=(-1, 0, 2), Reward=14.864, State=[9069.   20.   71.]
# episode 4, Day 25: Action=(1, 1, -2), Reward=15.414, State=[9070.   21.   69.]
# episode 4, Day 26: Action=(-2, -1, -2), Reward=19.311, State=[9068.   20.   67.]
# episode 4, Day 27: Action=(-1, 0, 2), Reward=22.095, State=[9067.   20.   69.]
# episode 4, Day 28: Action=(-1, 0, 2), Reward=25.233, State=[9066.   20.   71.]
# episode 4, Day 29: Action=(1, 1, -2), Reward=25.997, State=[9067.   21.   69.]
# episode 4, Day 30: Action=(-2, -1, -2), Reward=32.310, State=[9065.   20.   67.]
# episode 4, Day 31: Action=(-1, 0, 2), Reward=36.628, State=[9064.   20.   69.]
# episode 4, Day 32: Action=(-1, 0, 2), Reward=41.390, State=[9063.   20.   71.]
# episode 4, Day 33: Action=(1, 1, -2), Reward=42.149, State=[9064.   21.   69.]
# episode 4, Day 34: Action=(-2, -1, -2), Reward=51.722, State=[9062.   20.   67.]
# episode 4, Day 35: Action=(-1, 0, 2), Reward=57.745, State=[9061.   20.   69.]
# episode 4, Day 36: Action=(-1, 0, 2), Reward=64.136, State=[9060.   20.   71.]
# episode 4, Day 37: Action=(1, 1, -2), Reward=64.068, State=[9061.   21.   69.]
# episode 4, Day 38: Action=(-2, -1, -2), Reward=77.067, State=[9059.   20.   67.]
# episode 4, Day 39: Action=(-1, 0, 2), Reward=83.999, State=[9058.   20.   69.]
# episode 4, Day 40: Action=(-1, 0, 2), Reward=90.839, State=[9057.   20.   71.]
# episode 4, Day 41: Action=(1, 1, -2), Reward=88.121, State=[9058.   21.   69.]
# episode 4, Day 42: Action=(-2, -1, -2), Reward=102.931, State=[9056.   20.   67.]
# episode 4, Day 43: Action=(-1, 0, 2), Reward=108.346, State=[9055.   20.   69.]
# episode 4, Day 44: Action=(-1, 0, 2), Reward=112.835, State=[9054.   20.   71.]
# episode 4, Day 45: Action=(1, 1, -2), Reward=105.131, State=[9055.   21.   69.]
# episode 4, Day 46: Action=(-2, -1, -2), Reward=118.117, State=[9053.   20.   67.]
# episode 4, Day 47: Action=(-1, 0, 2), Reward=118.876, State=[9052.   20.   69.]
# episode 4, Day 48: Action=(-1, 0, 2), Reward=118.150, State=[9051.   20.   71.]
# episode 4, Day 49: Action=(1, 1, -2), Reward=104.912, State=[9052.   21.   69.]
# episode 4, Day 50: Action=(-2, -1, -2), Reward=112.769, State=[9050.   20.   67.]
# episode 4, Day 51: Action=(-1, 0, 2), Reward=108.042, State=[9049.   20.   69.]
# episode 4, Day 52: Action=(-1, 0, 2), Reward=102.254, State=[9048.   20.   71.]
# episode 4, Day 53: Action=(1, 1, -2), Reward=86.532, State=[9049.   21.   69.]
# episode 4, Day 54: Action=(-2, -1, -2), Reward=89.189, State=[9047.   20.   67.]
# episode 4, Day 55: Action=(-1, 0, 2), Reward=81.704, State=[9046.   20.   69.]
# episode 4, Day 56: Action=(-1, 0, 2), Reward=74.111, State=[9045.   20.   71.]
# episode 4, Day 57: Action=(1, 1, -2), Reward=60.263, State=[9046.   21.   69.]
# episode 4, Day 58: Action=(-2, -1, -2), Reward=60.096, State=[9044.   20.   67.]
# episode 4, Day 59: Action=(-1, 0, 2), Reward=53.209, State=[9043.   20.   69.]
# episode 4, Day 60: Action=(-1, 0, 2), Reward=46.793, State=[9042.   20.   71.]
# episode 4, Day 61: Action=(1, 1, -2), Reward=36.996, State=[9043.   21.   69.]
# episode 4, Day 62: Action=(-2, -1, -2), Reward=36.089, State=[9041.   20.   67.]
# episode 4, Day 63: Action=(-1, 0, 2), Reward=31.249, State=[9040.   20.   69.]
# episode 4, Day 64: Action=(-1, 0, 2), Reward=26.948, State=[9039.   20.   71.]
# episode 4, Day 65: Action=(1, 1, -2), Reward=20.933, State=[9040.   21.   69.]
# episode 4, Day 66: Action=(-2, -1, -2), Reward=20.159, State=[9038.   20.   67.]
# episode 4, Day 67: Action=(-1, 0, 2), Reward=17.228, State=[9037.   20.   69.]
# episode 4, Day 68: Action=(-1, 0, 2), Reward=14.690, State=[9036.   20.   71.]
# episode 4, Day 69: Action=(1, 1, -2), Reward=11.290, State=[9037.   21.   69.]
# episode 4, Day 70: Action=(-2, -1, -2), Reward=10.804, State=[9035.   20.   67.]
# episode 4, Day 71: Action=(-1, 0, 2), Reward=9.167, State=[9034.   20.   69.]
# episode 4, Day 72: Action=(-1, 0, 2), Reward=7.768, State=[9033.   20.   71.]
# episode 4, Day 73: Action=(1, 1, -2), Reward=5.928, State=[9034.   21.   69.]
# episode 4, Day 74: Action=(-2, -1, -2), Reward=5.663, State=[9032.   20.   67.]
# episode 4, Day 75: Action=(-1, 0, 2), Reward=4.786, State=[9031.   20.   69.]
# episode 4, Day 76: Action=(-1, 0, 2), Reward=4.043, State=[9030.   20.   71.]
# episode 4, Day 77: Action=(1, 1, -2), Reward=3.065, State=[9031.   21.   69.]
# episode 4, Day 78: Action=(-2, -1, -2), Reward=2.935, State=[9029.   20.   67.]
# episode 4, Day 79: Action=(-1, 0, 2), Reward=2.476, State=[9028.   20.   69.]
# episode 4, Day 80: Action=(-1, 0, 2), Reward=2.088, State=[9027.   20.   71.]
# episode 4, Day 81: Action=(1, 1, -2), Reward=1.569, State=[9028.   21.   69.]
# episode 4, Day 82: Action=(-2, -1, -2), Reward=1.514, State=[9026.   20.   67.]
# episode 4, Day 83: Action=(-1, 0, 2), Reward=1.276, State=[9025.   20.   69.]
# episode 4, Day 84: Action=(-1, 0, 2), Reward=1.075, State=[9024.   20.   71.]
# episode 4, Day 85: Action=(1, 1, -2), Reward=0.796, State=[9025.   21.   69.]
# episode 4, Day 86: Action=(-2, -1, -2), Reward=0.780, State=[9023.   20.   67.]
# episode 4, Day 87: Action=(-1, 0, 2), Reward=0.657, State=[9022.   20.   69.]
# episode 4, Day 88: Action=(-1, 0, 2), Reward=0.553, State=[9021.   20.   71.]
# episode 4, Day 89: Action=(1, 1, -2), Reward=0.398, State=[9022.   21.   69.]
# episode 4, Day 90: Action=(-2, -1, -2), Reward=0.403, State=[9020.   20.   67.]
